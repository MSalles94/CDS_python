# %%
from A0_data import read_data,clean_data

data=read_data()

data=clean_data(data=data)
# Out:
# shape:  (4467, 20)

# %%
from datetime import datetime

datetime(2022,4,2)
# Out:
# datetime.datetime(2022, 4, 2, 0, 0)

# %%
data
# Out:
#           ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0     0x4607     INDORES13DEL02                   37                      4.9
# 1     0xb379     BANGRES18DEL02                   34                      4.5
# 2     0x5d6d     BANGRES19DEL01                   23                      4.4
# 3     0x7a6a    COIMBRES13DEL02                   38                      4.7
# 4     0x70a2     CHENRES12DEL01                   32                      4.6
# ...      ...                ...                  ...                      ...
# 4460  0xdec8      KOCRES16DEL03                   30                      4.8
# 4461  0xdd08      KOCRES03DEL03                   34                      4.9
# 4462  0x2226      SURRES16DEL03                   34                      4.8
# 4463  0xdf39      BHPRES04DEL02                   37                      4.8
# 4465  0x363d     INDORES13DEL03                   34                      4.6
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0               22.745049             75.892471                   22.765049
# 1               12.913041             77.683237                   13.043041
# 2               12.914264             77.678400                   12.924264
# 3               11.003669             76.976494                   11.053669
# 4               12.972793             80.249982                   13.012793
# ...                   ...                   ...                         ...
# 4460            10.003064             76.307589                   10.033064
# 4461            10.020683             76.310631                   10.050683
# 4462            21.160437             72.774209                   21.220437
# 4463            23.184992             77.417227                   23.264992
# 4465            22.745049             75.892471                   22.835049
#
#       Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# 0                       75.912471 2022-03-19    11:30:00          11:45:00
# 1                       77.813237 2022-03-25    19:45:00          19:50:00
# 2                       77.688400 2022-03-19    08:30:00          08:45:00
# 3                       77.026494 2022-04-05    18:00:00          18:10:00
# 4                       80.289982 2022-03-26    13:30:00          13:45:00
# ...                           ...        ...         ...               ...
# 4460                    76.337589 2022-02-11    20:45:00          20:50:00
# 4461                    76.340631 2022-02-17    20:50:00          20:55:00
# 4462                    72.834209 2022-04-01    17:25:00          17:30:00
# 4463                    77.497227 2022-02-16    22:30:00          22:40:00
# 4465                    75.982471 2022-03-23    22:00:00          22:15:00
#
#           Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0          conditions Sunny                 High                  2
# 1         conditions Stormy                  Jam                  2
# 2     conditions Sandstorms                  Low                  0
# 3          conditions Sunny               Medium                  0
# 4         conditions Cloudy                 High                  1
# ...                     ...                  ...                ...
# 4460       conditions Sunny                  Jam                  0
# 4461       conditions Sunny                  Jam                  1
# 4462      conditions Cloudy               Medium                  1
# 4463  conditions Sandstorms                  Low                  2
# 4465       conditions Sunny                  Jam                  1
#
#      Type_of_order   Type_of_vehicle  multiple_deliveries Festival  \
# 0            Snack        motorcycle                    0       No
# 1            Snack           scooter                    1       No
# 2           Drinks        motorcycle                    1       No
# 3           Buffet        motorcycle                    1       No
# 4            Snack           scooter                    1       No
# ...            ...               ...                  ...      ...
# 4460          Meal        motorcycle                    0       No
# 4461        Drinks        motorcycle                    0       No
# 4462          Meal        motorcycle                    1       No
# 4463          Meal  electric_scooter                    1       No
# 4465        Drinks        motorcycle                    1       No
#
#                City Time_taken(min)
# 0             Urban        (min) 24
# 1     Metropolitian        (min) 33
# 2             Urban        (min) 26
# 3     Metropolitian        (min) 21
# 4     Metropolitian        (min) 30
# ...             ...             ...
# 4460  Metropolitian        (min) 22
# 4461  Metropolitian        (min) 23
# 4462  Metropolitian        (min) 17
# 4463          Urban        (min) 26
# 4465          Urban        (min) 22
#
# [4028 rows x 20 columns]

# %% [markdown]
# ## VISAO: ENTREGADORES

# %% [markdown]
# ### 1. Menor e maior idade dos entregadores

# %%
def responder(data):
    menor=data['Delivery_person_Age'].min()
    maior=data['Delivery_person_Age'].max()

    print(f' A maior idade é: {maior}')
    print(f' A menor idade é: {menor}')

responder(data)
# Out:
#  A maior idade é: 39
#  A menor idade é: 20

# %% [markdown]
# ### 2. A pior condição de veículo

# %%
def responder(data):
    pior=data['Vehicle_condition'].min()
    melhor=data['Vehicle_condition'].max()

    print(f'A pior condição de veículo é: {pior} ')
    print(f'A melhor condição de veículo é: {melhor} ')

responder(data)
# Out:
# A pior condição de veículo é: 0
# A melhor condição de veículo é: 2

# %% [markdown]
# ### 3. A avaliação média por entregador

# %%
def responder(data):
    df_rating=data.groupby(['Delivery_person_ID'])[['Delivery_person_Ratings']].mean().reset_index()
    display(df_rating)


responder(data)
# Out:
#      Delivery_person_ID  Delivery_person_Ratings
# 0        AGRRES010DEL01                 4.700000
# 1        AGRRES010DEL02                 4.700000
# 2         AGRRES01DEL02                 4.400000
# 3         AGRRES01DEL03                 4.800000
# 4         AGRRES02DEL02                 4.900000
# ...                 ...                      ...
# 1115      VADRES19DEL02                 4.528571
# 1116      VADRES19DEL03                 4.640000
# 1117      VADRES20DEL01                 4.680000
# 1118      VADRES20DEL02                 4.533333
# 1119      VADRES20DEL03                 4.800000
#
# [1120 rows x 2 columns]

# %% [markdown]
# ### 4. Avaliação média e o desvio padrão por tipo de tráfego

# %%
def responder(data):
    df_rating=data.groupby(['Road_traffic_density'])[['Delivery_person_Ratings']].agg(['mean', 'std']).reset_index()
    display(df_rating)


responder(data)

# %% [markdown]
# ### 5. Avaliação média e desvio por condição climatica

# %%
def responder(data):
    df_rating=data.groupby(['Weatherconditions'])[['Delivery_person_Ratings']].agg(['mean', 'std']).reset_index()
    display(df_rating)


responder(data)

# %% [markdown]
# ### 6. top 10 entregadores mais rápidos

# %%
data

# %%
def responder(data):
    df_x=data.copy()

    df_x['tempo']=df_x['Time_taken(min)'].map(lambda x:float(x.replace('(min)','')))
    df_x=df_x.groupby(['City','Delivery_person_ID'])[['tempo']].mean().reset_index().sort_values(by='tempo')

    display(df_x.head(10))



responder(data)

# %% [markdown]
# ### 7. top 10 entregadores mais lentos

# %%
def responder(data):
    df_x=data.copy()

    df_x['tempo']=df_x['Time_taken(min)'].map(lambda x:float(x.replace('(min)','')))
    df_x=df_x.groupby(['City','Delivery_person_ID'])[['tempo']].mean().reset_index().sort_values(by='tempo',ascending=False)

    display(df_x.head(10))



responder(data)

# %% [markdown]
# ## VISÃO RESTAURANTES

# %% [markdown]
# ### 1. A quantidade de entregadores unicos

# %%
def responder(data):
    
    display(data)



responder(data)
# Out:
#           ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0     0x4607     INDORES13DEL02                   37                      4.9
# 1     0xb379     BANGRES18DEL02                   34                      4.5
# 2     0x5d6d     BANGRES19DEL01                   23                      4.4
# 3     0x7a6a    COIMBRES13DEL02                   38                      4.7
# 4     0x70a2     CHENRES12DEL01                   32                      4.6
# ...      ...                ...                  ...                      ...
# 4460  0xdec8      KOCRES16DEL03                   30                      4.8
# 4461  0xdd08      KOCRES03DEL03                   34                      4.9
# 4462  0x2226      SURRES16DEL03                   34                      4.8
# 4463  0xdf39      BHPRES04DEL02                   37                      4.8
# 4465  0x363d     INDORES13DEL03                   34                      4.6
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0               22.745049             75.892471                   22.765049
# 1               12.913041             77.683237                   13.043041
# 2               12.914264             77.678400                   12.924264
# 3               11.003669             76.976494                   11.053669
# 4               12.972793             80.249982                   13.012793
# ...                   ...                   ...                         ...
# 4460            10.003064             76.307589                   10.033064
# 4461            10.020683             76.310631                   10.050683
# 4462            21.160437             72.774209                   21.220437
# 4463            23.184992             77.417227                   23.264992
# 4465            22.745049             75.892471                   22.835049
#
#       Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# 0                       75.912471 2022-03-19    11:30:00          11:45:00
# 1                       77.813237 2022-03-25    19:45:00          19:50:00
# 2                       77.688400 2022-03-19    08:30:00          08:45:00
# 3                       77.026494 2022-04-05    18:00:00          18:10:00
# 4                       80.289982 2022-03-26    13:30:00          13:45:00
# ...                           ...        ...         ...               ...
# 4460                    76.337589 2022-02-11    20:45:00          20:50:00
# 4461                    76.340631 2022-02-17    20:50:00          20:55:00
# 4462                    72.834209 2022-04-01    17:25:00          17:30:00
# 4463                    77.497227 2022-02-16    22:30:00          22:40:00
# 4465                    75.982471 2022-03-23    22:00:00          22:15:00
#
#           Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0          conditions Sunny                 High                  2
# 1         conditions Stormy                  Jam                  2
# 2     conditions Sandstorms                  Low                  0
# 3          conditions Sunny               Medium                  0
# 4         conditions Cloudy                 High                  1
# ...                     ...                  ...                ...
# 4460       conditions Sunny                  Jam                  0
# 4461       conditions Sunny                  Jam                  1
# 4462      conditions Cloudy               Medium                  1
# 4463  conditions Sandstorms                  Low                  2
# 4465       conditions Sunny                  Jam                  1
#
#      Type_of_order   Type_of_vehicle  multiple_deliveries Festival  \
# 0            Snack        motorcycle                    0       No
# 1            Snack           scooter                    1       No
# 2           Drinks        motorcycle                    1       No
# 3           Buffet        motorcycle                    1       No
# 4            Snack           scooter                    1       No
# ...            ...               ...                  ...      ...
# 4460          Meal        motorcycle                    0       No
# 4461        Drinks        motorcycle                    0       No
# 4462          Meal        motorcycle                    1       No
# 4463          Meal  electric_scooter                    1       No
# 4465        Drinks        motorcycle                    1       No
#
#                City Time_taken(min)
# 0             Urban        (min) 24
# 1     Metropolitian        (min) 33
# 2             Urban        (min) 26
# 3     Metropolitian        (min) 21
# 4     Metropolitian        (min) 30
# ...             ...             ...
# 4460  Metropolitian        (min) 22
# 4461  Metropolitian        (min) 23
# 4462  Metropolitian        (min) 17
# 4463          Urban        (min) 26
# 4465          Urban        (min) 22
#
# [4028 rows x 20 columns]

# %% [markdown]
# ### 2. Distância média entre restaurante e local de entrega

# %% [markdown]
# ### 3. Tempo médio e desvio de entrega por cidade

# %% [markdown]
# ### 4 . Tempo médio e desvio por cidade e tipo de pedido

# %% [markdown]
# ### 5. Tempo médio e desvio por cidade e tipo de trafego

# %% [markdown]
# ### 6. Tempo médio e desvio durante festivais

# %%
columns = [
'City',
'Road_traffic_density',
'Delivery_location_latitude',
'Delivery_location_longitude'
]
tabela=data[columns]

tabela=tabela.groupby(['City','Road_traffic_density']).median().reset_index()
from folium import Map,Marker
map_=Map(zoom_start=11)
for  index, location_info in tabela.iterrows():
    
    Marker(
        [location_info['Delivery_location_latitude'],
        location_info['Delivery_location_longitude']],
        popup=location_info[['City','Road_traffic_density']]
    ).add_to( map_ )
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8832a405375b4ff2f570347aae6cf5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8832a405375b4ff2f570347aae6cf5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8832a405375b4ff2f570347aae6cf5d = L.map(
#                 &quot;map_b8832a405375b4ff2f570347aae6cf5d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26d01612d58e559e78d47d28718c1486 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_26d01612d58e559e78d47d28718c1486.addTo(map_b8832a405375b4ff2f570347aae6cf5d);
#
#
#             var marker_5f887046aa90699bbc2eb8a3f6d2fa61 = L.marker(
#                 [18.56144, 75.921991],
#                 {}
#             ).addTo(map_b8832a405375b4ff2f570347aae6cf5d);
#
#
#         var popup_b1900dc584a441036b939d196c547d64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d23f6603d02f2009b6a0bd46f660653 = $(`&lt;div id=&quot;html_7d23f6603d02f2009b6a0bd46f660653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City                    Metropolitian Road_traffic_density             High Name: 0, dtype: object&lt;/div&gt;`)[0];
#                 popup_b1900dc584a441036b939d196c547d64.setContent(html_7d23f6603d02f2009b6a0bd46f660653);
#
#
#
#         marker_5f887046aa90699bbc2eb8a3f6d2fa61.bindPopup(popup_b1900dc584a441036b939d196c547d64)
#         ;
#
#
#
#
#             var marker_6e60a5add80800f4d85706e1c9bbd097 = L.marker(
#                 [18.621945, 76.6496485],
#                 {}
#             ).addTo(map_b8832a405375b4ff2f570347aae6cf5d);
#
#
#         var popup_d6204e30c563476410ecc51098ad18c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de6fc7ed71f8e63b236be29fa9c0a30b = $(`&lt;div id=&quot;html_de6fc7ed71f8e63b236be29fa9c0a30b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City                    Metropolitian Road_traffic_density              Jam Name: 1, dtype: object&lt;/div&gt;`)[0];
#                 popup_d6204e30c563476410ecc51098ad18c0.setContent(html_de6fc7ed71f8e63b236be29fa9c0a30b);
#
#
#
#         marker_6e60a5add80800f4d85706e1c9bbd097.bindPopup(popup_d6204e30c563476410ecc51098ad18c0)
#         ;
#
#
#
#
#             var marker_27cb383824ac6c5ec5a4d1d35a15576a = L.marker(
#                 [18.947584, 75.923112],
#                 {}
#             ).addTo(map_b8832a405375b4ff2f570347aae6cf5d);
#
#
#         var popup_ce2c6d2aa91cd04a8fef5d3e100282af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0154e3ce6b222bb0af69f02b12f55ba1 = $(`&lt;div id=&quot;html_0154e3ce6b222bb0af69f02b12f55ba1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City                    Metropolitian Road_traffic_density              Low Name: 2, dtype: object&lt;/div&gt;`)[0];
#                 popup_ce2c6d2aa91cd04a8fef5d3e100282af.setContent(html_0154e3ce6b222bb0af69f02b12f55ba1);
#
#
#
#         marker_27cb383824ac6c5ec5a4d1d35a15576a.bindPopup(popup_ce2c6d2aa91cd04a8fef5d3e100282af)
#         ;
#
#
#
#
#             var marker_8391b60465666b7432630764feac68b5 = L.marker(
#                 [18.642718, 76.366958],
#                 {}
#             ).addTo(map_b8832a405375b4ff2f570347aae6cf5d);
#
#
#         var popup_05c18637987cd13dfd399152ae572112 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_079ee41a15c97c2ff177a3a0aeacb418 = $(`&lt;div id=&quot;html_079ee41a15c97c2ff177a3a0aeacb418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City                    Metropolitian Road_traffic_density           Medium Name: 3, dtype: object&lt;/div&gt;`)[0];
#                 popup_05c18637987cd13dfd399152ae572112.setContent(html_079ee41a15c97c2ff177a3a0aeacb418);
#
#
#
#         marker_8391b60465666b7432630764feac68b5.bindPopup(popup_05c18637987cd13dfd399152ae572112)
#         ;
#
#
#
#
#             var marker_ad1116614fe8e80d7af5ce7c446b33fa = L.marker(
#                 [18.576718, 73.870328],
#                 {}
#             ).addTo(map_b8832a405375b4ff2f570347aae6cf5d);
#
#
#         var popup_7cc084183e90b2dae1a20b5997561127 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47f984c70e7a804cb00d754acecbf005 = $(`&lt;div id=&quot;html_47f984c70e7a804cb00d754acecbf005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City                    Semi-Urban Road_traffic_density          High Name: 4, dtype: object&lt;/div&gt;`)[0];
#                 popup_7cc084183e90b2dae1a20
